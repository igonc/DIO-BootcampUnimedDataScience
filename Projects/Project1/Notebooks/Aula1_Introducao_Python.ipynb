# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
#Esse é um comentário em Python

# %%
#Multiplicação
2 * 2
# Out:
# 4

# %%
#Divisão
10//2
# Out:
# 5

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
#Criando uma variável do tipo string
frase = "Python para análise de dados"

# %%
frase[0:6]
# Out:
# 'Python'

# %%
frase[0:]
# Out:
# 'Python para análise de dados'

# %%
frase[12:]
# Out:
# 'análise de dados'

# %%
frase[:12]
# Out:
# 'Python para '

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase = frase.title()
print(frase)
# Out:
# Python Para Análise De Dados

# %%
frase.replace("Python","Frases")
# Out:
# 'Frases Para Análise De Dados'

# %%
frase
# Out:
# 'Python Para Análise De Dados'

# %%
frase1 = frase.replace("Python", "Frases")
print(frase)
print(frase1)
# Out:
# Python Para Análise De Dados
# Frases Para Análise De Dados
